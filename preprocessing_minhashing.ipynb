# %%
from pathlib import Path
import pandas as pd
import numpy as np

# %%
#path to preprocessed dataset
path = Path(r"H:\My Drive\DTU\Computational Tools\Books_rating_preprocessed.csv")
df = pd.read_csv(path)

# %% [markdown]
# ## Preprocessing for Minhashing
