# %% [markdown]
# ### Prepare subset of data from original subset with 100 reviews

# %%
import pandas as pd

# %%
data=pd.read_csv("/Users/sararedaelli/Desktop/AMAZON REVIEWS/Book_rating_cleaned_engl_subset.csv")
print(data.shape)
print(data.columns)
# Out:
# (500000, 4)
# Index(['Id', 'review/score', 'cleanText', 'lang'], dtype='object')

# %%
#get a subset of the data and save it 
subset=data.sample(n=100, random_state=42)
subset.to_csv("/Users/sararedaelli/Desktop/AMAZON REVIEWS/AmazonReview/100_data_subset.csv", index=False)
