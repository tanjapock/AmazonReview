# %%
path = "data/Books_rating_embeddings/part-00297.parquet"
with open(path, "rb") as f:
    head = f.read(4)
    f.seek(-4, 2)
    tail = f.read(4)
print("HEAD:", head, "TAIL:", tail)
# Out:
# HEAD: b'PAR1' TAIL: b'PAR1'

# %%
import pandas as pd
df_csv = pd.read_csv("/zhome/3d/c/222266/ComputationalTools/AmazonReview/data/Books_rating_cleaned_only_eng.csv")
print(df_csv.head())
# Out:
#            Id  review/score  \
# 0  1882931173           4.0
# 1  0826414346           5.0
# 2  0826414346           5.0
# 3  0826414346           4.0
# 4  0826414346           4.0
#
#                                            cleanText lang
# 0  This is only for Julie Strain fans. It's a col...   en
# 1  I don't care much for Dr. Seuss but after read...   en
# 2  If people become the books they read and if "t...   en
# 3  Theodore Seuss Geisel (1904-1991), aka "Dr. Se...   en
# 4  Philip Nel - Dr. Seuss: American IconThis is b...   en

# %%
import pandas as pd

# Parquet-Datei einlesen
df = pd.read_parquet("data/Books_rating_embeddings/part-00297.parquet")

# Erste 5 Zeilen anzeigen
print(df.head())
# Out:
#        row_id review/score                                          cleanText  \
# 0  0451201450          4.0  I really loved this book and couldn't put it d...
# 1  0451201450          2.0  I just couldn't get into this book. It just se...
# 2  0451201450          3.0  Overall I enjoyed this book, and will go on to...
# 3  0451201450          4.0  I really liked this book, I was moved to tears...
# 4  0451201450          5.0  This book has really touched me. It hits close...
#
#                                            embedding
# 0  [-0.14411029, -0.032927424, -0.35155308, 0.044...
# 1  [0.15537396, -0.16763234, -0.10534853, 0.05015...
# 2  [-0.034059674, -0.28799456, -0.1612789, -0.049...
# 3  [-0.12269137, -0.051754467, -0.28807598, 0.407...
# 4  [0.008900793, 0.129087, -0.21674785, 0.0387849...
